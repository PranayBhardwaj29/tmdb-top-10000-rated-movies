# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=<<API_KEY>>&language=en-US&page=1')

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count']]

# %%
temp_df.head()
# Out:
#         id                     title  \
# 0  1007757                   Swapped
# 1      278  The Shawshank Redemption
# 2   936075                   Michael
# 3   687163         Project Hail Mary
# 4      238             The Godfather
#
#                                             overview release_date  popularity  \
# 0  A small woodland creature and a majestic bird,...   2026-05-01    126.5761
# 1  Imprisoned in the 1940s for the double murder ...   1994-09-23    110.5352
# 2  The story of Michael Jackson, one of the most ...   2026-04-22    321.7840
# 3  Science teacher Ryland Grace wakes up on a spa...   2026-03-15    129.8917
# 4  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     40.9483
#
#    vote_average  vote_count
# 0         8.956        1826
# 1         8.723       30649
# 2         8.710        3159
# 3         8.692        5486
# 4         8.687       23089

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1, 501):
  response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=<<API_KEY>>&language=en-US&page={}'.format(i))

  temp_df = pd.DataFrame(response.json()['results'])[['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count']]

  df = pd.concat([df, temp_df], ignore_index=True)

# %%
df
# Out:
#            id                     title  \
# 0     1007757                   Swapped
# 1         278  The Shawshank Redemption
# 2      936075                   Michael
# 3      687163         Project Hail Mary
# 4         238             The Godfather
# ...       ...                       ...
# 9995    10375                     D-Tox
# 9996   842934                Poker Face
# 9997   419472            The Polka King
# 9998   301846                      Howl
# 9999    82679                  Fun Size
#
#                                                overview release_date  \
# 0     A small woodland creature and a majestic bird,...   2026-05-01
# 1     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 2     The story of Michael Jackson, one of the most ...   2026-04-22
# 3     Science teacher Ryland Grace wakes up on a spa...   2026-03-15
# 4     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# ...                                                 ...          ...
# 9995  A disgraced FBI agent with a drinking problem ...   2002-01-04
# 9996  A yearly high-stakes poker game between childh...   2022-11-16
# 9997  Local Pennsylvania polka legend Jan Lewan deve...   2017-01-22
# 9998  When passengers on a train are attacked by a c...   2015-10-01
# 9999  Wren's Halloween plans go awry when she's made...   2012-10-24
#
#       popularity  vote_average  vote_count
# 0       126.5761         8.956        1826
# 1       110.5352         8.723       30649
# 2       321.7840         8.710        3159
# 3       129.8917         8.692        5486
# 4        40.9483         8.687       23089
# ...          ...           ...         ...
# 9995      2.6135         5.578         721
# 9996      3.8153         5.567         435
# 9997      1.3822         5.577         326
# 9998      2.0144         5.582         568
# 9999      2.9241         5.567         449
#
# [10000 rows x 7 columns]

# %%
df.shape
# Out:
# (10000, 7)

# %%
df.to_csv('movies.csv')
